# %% [markdown]
# <a href="https://colab.research.google.com/github/Krzesimir13/DataQuest/blob/main/automobiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Linear Regression

# %% [markdown]
# ##1. Preparing the environment and uploading the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
np.set_printoptions(precision=3, suppress=False)
pd.options.display.precision = 3

# %%
raw_data = pd.read_csv('automobiles.csv')
auto = raw_data.copy()
